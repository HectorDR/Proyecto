# %%
import requests
url= "https://www.bankofcanada.ca/terms"

# %%
import json
import requests

mv_data_json = requests.get('https://data.ny.gov/resource/xe9x-a24f.json')

mv_list_recs = json.loads(mv_data_json.text)

print(mv_list_recs[0])

# %%
 
bc_data_json = requests.get('https://www.bankofcanada.ca/valet/series/FXAUDCAD')

# %%
https://www.bankofcanada.ca/valet/series/FXAUDCAD

# %%
url = 'http://climatedataapi.worldbank.org/climateweb/rest/v1/country/cru/tas/year/CAN.csv'
response = requests.get(url)
if response.status_code != 200:
    print('Failed to get data:', response.status_code)
else:
    print('First 100 characters of data are')
    print(response.text[:100])

# %%
url = 'https://www.bankofcanada.ca/valet/observations/FXUSDCAD?start_date=2020-03-09'
response = requests.get(url)
if response.status_code != 200:
    print('Failed to get data:', response.status_code)
else:
    print('First 100 characters of data are')
    print(response.text[:2000])

# %%
response1 = json.loads(response.text)
response1

# %%
#import pandas as pd
#response2 = pd.DataFrame(response1)
#response2.head(10)

# %%
url = 'https://www.bankofcanada.ca/valet/lists/series'
response = requests.get(url)
if response.status_code != 200:
    print('Failed to get data:', response.status_code)
else:
    print('First 100 characters of data are')
    print(response.text[:2000])

# %%
response1 = json.loads(response.text)
response1

# %%
url = 'https://www.bankofcanada.ca/valet/series/V36926'
response = requests.get(url)
if response.status_code != 200:
    print('Failed to get data:', response.status_code)
else:
    print('First 100 characters of data are')
    print(response.text[:2000])

# %%
import json
import requests

# %%
url ='https://www150.statcan.gc.ca/n1/dai-quo/ssi/homepage/daily-banner-eng.json'
response = requests.get(url)
response1 = json.loads(response.text)
response1
# Out:
# {'daily': {'article': [{'date': 'March 20, 2020',
#     'photo': '/dai-quo/ssi/homepage/release_photo/28.jpg',
#     'title': 'Retail trade, January 2020',
#     'summary': 'Retail sales rose for the third consecutive month, up 0.4% to $52.0 billion in January. While the impacts of the coronavirus on the retail trade sector will be more noticeable in subsequent months, respondent comments for February note that business activities have been impacted. ',
#     'link': '/daily-quotidien/200320/dq200320a-eng.htm'},
#    {'date': 'March 18, 2020',
#     'photo': '/dai-quo/ssi/homepage/release_photo/3.jpg',
#     'title': 'Consumer Price Index, February 2020',
#     'summary': 'The Consumer Price Index (CPI) rose 2.2% on a year-over-year basis in February, down from a 2.4% increase in January. On a seasonally adjusted monthly basis, the CPI was up 0.1% in February, matching the increase in January.',
#     'link': '/daily-quotidien/200318/dq200318a-eng.htm'},
# ...

# %%
url =  'https://www150.statcan.gc.ca/t1/wds/rest/getFullTableDownloadCSV/10013901/en'
response = requests.get(url)
response1 = json.loads(response.text)
response1
# Out:
# {'status': 'SUCCESS',
#  'object': 'https://www150.statcan.gc.ca/n1/tbl/csv/10013901-eng.zip'}

# %% [raw]
# from zipfile import ZipFile

# %%
from zipfile import ZipFile

# %%
# Create a ZipFile Object and load sample.zip in it
with ZipFile('response1', 'r') as zipObj:
   # Extract all the contents of zip file in current directory
   zipObj.extractall()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-1cb114fe6eec> in <module>
#       1 # Create a ZipFile Object and load sample.zip in it
# ----> 2 with ZipFile('response1', 'r') as zipObj:
#       3    # Extract all the contents of zip file in current directory
#       4    zipObj.extractall()
#
# /anaconda3/lib/python3.7/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel)
#    1202             while True:
#    1203                 try:
# -> 1204                     self.fp = io.open(file, filemode)
#    1205                 except OSError:
#    1206                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'response1'
